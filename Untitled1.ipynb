# %% [markdown]
# <a href="https://colab.research.google.com/github/tanukushwaha/String-operations-in-C-/blob/master/Untitled1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import matplotlib
from matplotlib import pyplot as plt
plt.plot([1,2,3],[4,5,1])
plt.show()

# %%
from matplotlib import pyplot as plt
x=[5,8,1]
y=[12,13,14]

plt.plot(x,y)
plt.title("Epic Info")
plt.ylabel("y axis")
plt.xlabel("x axis")
plt.show()
